# %%
import pandas as pd

# %%
df = pd.read_csv("../data/transportation.csv", thousands=',')

# %%
df
# Out:
#                 ExpenseName stateAbbrev  stateFIPS countyortownName  \
# 0      expense.transportion          AL          1   Autauga County
# 1      expense.transportion          AL          1   Autauga County
# 2      expense.transportion          AL          1   Autauga County
# 3      expense.transportion          AL          1   Autauga County
# 4      expense.transportion          AL          1   Autauga County
# ...                     ...         ...        ...              ...
# 70165  expense.transportion          WY         56    Weston County
# 70166  expense.transportion          WY         56    Weston County
# 70167  expense.transportion          WY         56    Weston County
# 70168  expense.transportion          WY         56    Weston County
# 70169  expense.transportion          WY         56    Weston County
#
#        numadults  numkids  yearofdata  expense.transportation  Unnamed: 8  \
# 0              1        0        2021                    4359         NaN
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df['expense.transportation']
# Out:
# 0         4359
# 1         5318
# 2         6276
# 3         7235
# 4         8194
#          ...
# 70165    12818
# 70166    13894
# 70167    14971
# 70168    16047
# 70169    17123
# Name: expense.transportation, Length: 70170, dtype: int64

# %%
df
# Out:
#                 ExpenseName stateAbbrev  stateFIPS countyortownName  \
# 0      expense.transportion          AL          1   Autauga County
# 1      expense.transportion          AL          1   Autauga County
# 2      expense.transportion          AL          1   Autauga County
# 3      expense.transportion          AL          1   Autauga County
# 4      expense.transportion          AL          1   Autauga County
# ...                     ...         ...        ...              ...
# 70165  expense.transportion          WY         56    Weston County
# 70166  expense.transportion          WY         56    Weston County
# 70167  expense.transportion          WY         56    Weston County
# 70168  expense.transportion          WY         56    Weston County
# 70169  expense.transportion          WY         56    Weston County
#
#        numadults  numkids  yearofdata  expense.transportation
# 0              1        0        2021                    4359
# ...
